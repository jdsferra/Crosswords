# %%
### preliminary work
import pandas as pd
import chardet
import matplotlib.pyplot as plt
file = 'nytcrosswords.csv'
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
df = pd.read_csv(file, encoding = result['encoding'])


df.describe()
#34 missing word values (781,573 minus 781539) (NULL)
#10207 unique dates, 63,313 unique words check after NULL adjustment, 493935 clues (makes sense, more clues than words)
#puzzle with most clues is 5/16/1999 (181 words) (mode?), most common word is ERA
#most common clue is "JAI ___" - common crossword word with fewer uses/contexts than similar words ('ALAI')
# Out:
#              Date    Word     Clue
# count      781573  781539   781573
# unique      10207   63313   493935
# top     5/16/1999     ERA  Jai ___
# freq          181     634      122

# %%
#Investigate null values


nullmask = df.isnull().any(axis = 1)
nullrows = df[nullmask]
print(nullrows)
#lol, the null values are originally the word "NULL"! Need to replace Nans with "NULL"
df['Word'] = df ['Word'].fillna('NULL') #comment out to see
# Out:
#               Date Word                   Clue
# 24006   12/24/2020  NaN                   Zero
# 43275    4/17/2020  NaN                  Empty
# 67323     6/7/2019  NaN            Of no value
# 93805    6/24/2018  NaN     No longer in force
# 141809   10/1/2016  NaN    { }, in mathematics
# 157990    3/3/2016  NaN  Having no legal force
# 176711    7/2/2015  NaN                Invalid
# 189051   1/22/2015  NaN                  Empty
# 195559  10/29/2014  NaN                   Void
# 229912    8/7/2013  NaN   Empty, as a math set
# 251214  10/31/2012  NaN          Lacking value
# 295562   3/30/2011  NaN         Empty, in math
# 344370    7/1/2009  NaN                   Zero
# 350968    4/6/2009  NaN           ___ and void
# 447651  10/23/2005  NaN                Invalid
# 480418   8/18/2004  NaN                   Zero
# 488526    5/5/2004  NaN        No longer legal
# 510877   7/19/2003  NaN   Lacking any elements
# 522564   2/17/2003  NaN          Without value
# 540417   6/30/2002  NaN            Nonexistent
# 541820   6/11/2002  NaN        Legally invalid
# 552743   1/20/2002  NaN                   Zero
# 565265    8/8/2001  NaN              Aleph-___
# 577557    3/1/2001  NaN              Valueless
# 593284    8/7/2000  NaN        Partner of void
# 593445    8/6/2000  NaN                   Zero
# 641843  11/17/1998  NaN         Empty, in math
# 645122   10/6/1998  NaN              Not valid
# 663360   2/11/1998  NaN            Nonexistent
# 668141  12/11/1997  NaN            Nonexistent
# 746622   2/18/1995  NaN                Invalid
# 747460    2/7/1995  NaN         Void's partner
# 749010   1/17/1995  NaN         Void's partner
# 763735   7/10/1994  NaN                   Zero

# %%
#Want to be able to work with dates 
# Make sure dates are date objects and add column that indicates day of week (PD: Monday = 0 thru Sunday = 6)
df['Date'] = pd.to_datetime(df['Date'])
df['DayofWeek'] = df['Date'].dt.weekday
df['Date'].describe()
# Out:
# count                           781573
# mean     2007-11-06 12:23:01.220692480
# min                1993-11-21 00:00:00
# 25%                2000-11-08 00:00:00
# 50%                2007-11-04 00:00:00
# 75%                2014-11-01 00:00:00
# max                2021-10-31 00:00:00
# Name: Date, dtype: object

# %%
# Want to examine Word lengths, make separate column
df['lengths'] = df['Word'].apply(len)
df.describe()
# count values are all the same, confirms no nulls!
# Out:
#                                 Date      DayofWeek        lengths
# count                         781573  781573.000000  781573.000000
# mean   2007-11-06 12:23:01.220692480       3.241489       4.795542
# min              1993-11-21 00:00:00       0.000000       1.000000
# 25%              2000-11-08 00:00:00       1.000000       4.000000
# 50%              2007-11-04 00:00:00       3.000000       4.000000
# 75%              2014-11-01 00:00:00       5.000000       5.000000
# max              2021-10-31 00:00:00       6.000000      22.000000
# std                              NaN       2.134204       1.675419

# %%
#Want to examine vowel:consonant relationships in words.
#Make function that calculates proportion of vowels to word, make new col with this info

def vowelratio(myword):
    """
    Vowel Ratio Function:
    Input: word as string
    Returns: float representing proportion of vowels to the length of the total word
    """
    
    vowelcount = myword.count('A') + myword.count('E') + myword.count('I')\
                + myword.count('O') + myword.count('U') + myword.count('Y')
    
    return round((vowelcount/len(myword)), 3)

df['vowelratio'] = df['Word'].apply(vowelratio)

# %%
#prelim looking around- most common words
wordcounts = df['Word'].value_counts()
wordcounts
# Out:
# Word
# ERA                634
# AREA               534
# ERE                510
# ONE                510
# ELI                493
#                   ...
# COOKIESANDCREAM      1
# BIGBANDS             1
# PATPAULSEN           1
# HIKEUP               1
# YELLOWER             1
# Name: count, Length: 63314, dtype: int64

# %%
#most commonly used words
ax = wordcounts[:25].plot(kind = 'bar')
ax.set_ylabel('# of occurrences')
ax.set_xlabel('words')
ax.set_title('Most Common Words in NYT Crossword Puzzles 1993-2021')
# Out:
# Text(0.5, 1.0, 'Most Common Words in NYT Crossword Puzzles 1993-2021')

# %%
lengthcount = df.value_counts('lengths').sort_index().plot(kind = 'bar')
lengthcount.set_ylabel('# of occurrences')
lengthcount.set_title('Three to Five Letter Words Dominate')
# Out:
# Text(0.5, 1.0, 'Three to Five Letter Words Dominate')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 781573 entries, 0 to 781572
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Date        781573 non-null  datetime64[ns]
#  1   Word        781573 non-null  object
#  2   Clue        781573 non-null  object
#  3   DayofWeek   781573 non-null  int32
#  4   lengths     781573 non-null  int64
#  5   vowelratio  781573 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(1), object(2)
# memory usage: 32.8+ MB

# %%
df['DayofWeek'].value_counts() #number of clues basically goes down throughout week (words get longer)
# Out:
# DayofWeek
# 6    185922
# 0    106971
# 1    105562
# 2    103910
# 3    100480
# 4     90534
# 5     88194
# Name: count, dtype: int64

# %%
df['lengths'].value_counts() #want to examine the words with the least-common lengths.
# 1, 2, 16 through 22

outliers = [1, 2]
outliermask = df['lengths'].isin(outliers)
shorts = df[outliermask]
shorts
#two letter words are quite rare, NO and PI. What is the one-letter word?:
#64-Across, in 23-Down. Clues are not numbered or directioned in this dataset, instead of finding all this
#go to actual puzzle: https://www.xwordinfo.com/Crossword?date=10/31/2013
# 'DRACULA, in MIRRORS'= blank answer!
# Out:
#              Date Word                                               Clue  \
# 80172  2018-12-20   NO  With 38-Across, what a two-letter answer is in...
# 80174  2018-12-20   NO                                      See 35-Across
# 223435 2013-10-31                                   64-Across, in 23-Down
# 485629 2004-06-12   PI                               It's just past three
#
#         DayofWeek  lengths  vowelratio
# 80172           3        2         0.5
# 80174           3        2         0.5
# 223435          3        1         0.0
# 485629          5        2         0.5

# %%
#these less-common lengths are not long words, but rather proper nouns or turns of phrase (or turns on them)

outliers = range(16, 23)
outliermask = df['lengths'].isin(outliers)
longwords = df[outliermask]
pd.set_option('display.max_rows', 75)
longwords.sort_values(by = 'lengths', ascending = False)
# Out:
#              Date                    Word  \
# 76762  2019-02-03  THETRUTHWILLSETYOUFREE
# 215356 2014-02-13   ITSAMADMADMADMADWORLD
# 260451 2012-07-01   BORNONTHEFOURTHOFJULY
# 204390 2014-07-06   THESTARSPANGLEDBANNER
# 302230 2011-01-02    ATREEGROWSINBROOKLYN
# 425623 2006-08-06    GROSSNATIONALCONDUCT
# 24814  2020-12-13     RAIDERSOFTHELOSTARK
# 378484 2008-04-13     SERMONONTHEDISMOUNT
# 347298 2009-05-24      HOPESPRINGSETERNAL
# 159905 2016-02-07      TABLEOFDISCONTENTS
# 173025 2015-08-20      UPSTAIRSDOWNSTAIRS
# 370380 2008-07-27      UPSTAIRSDOWNSTAIRS
# 347254 2009-05-24      DIAMONDSAREFOREVER
# 226669 2013-09-18      ONCEBITTENTWICESHY
# 163910 2015-12-17       LONGISLANDICEDTEA
# 236576 2013-05-12       LOOKBEFOREYOULEAP
# 263658 2012-05-20       THESOUNDANDTHEFUR
# 302220 2011-01-02       ANAMERICANINPARIS
# 351580 2009-03-29       ANAMERICANINPARIS
# 172249 2015-08-30       CLOTHESMAKETHEMAN
# 172201 2015-08-30       LOOKBEFOREYOULEAP
# 166838 2015-11-08       CONANTHEBARBARIAN
# 343040 2009-07-19       TOWNWITHOUTPURITY
# 15054  2021-04-18       MISSIONIMPOSSIBLE
# 224771 2013-10-13       MISSIONIMPOSSIBLE
# 641697 1998-11-19       GREATEXPECTATIONS
# 577007 2001-03-08       GREATEXPECTATIONS
# 48156  2020-02-13       REVERSEDICTIONARY
# 716632 1996-03-17       SYDNEYGREENSTREET
# 63994  2019-07-21       THEEAGLEHASLANDED
# 681775 1997-06-15       WEARINGOFTHEGREEN
# 86840  2018-09-23       TREACHERYOFIMAGES
# 429423 2006-06-18       TURNTHEOTHERCHEEK
# 516223 2003-05-11       THENAKEDANDTHEDEA
# 137144 2016-12-01       ANNEOFGREENGABLES
# 355895 2009-02-01        PASSINTERFERENCE
# 626359 1999-06-06        THEMALTESEFALCON
# 632912 1999-03-14        FRENCHCONNECTION
# 476891 2004-10-03        RIDEANDPREJUDICE
# 545155 2002-04-28        SHRINKINGVIOLETS
# 402038 2007-06-10        MANHATTANPROJECT
# 708574 1996-06-30        FLYINTHEOINTMENT
# 353710 2009-03-01        WRECKLESSDRIVING
# 476928 2004-10-03        THETURNOFTHECREW
# 756094 1994-10-16        FLYINTHEOINTMENT
# 781524 1993-11-21        ACLOCKWORKORANGE
# 474825 2004-10-31        PASSINTERFERENCE
# 594    2021-10-24        DESIGNATEDHITTER
# 343340 2009-07-14        ATALEOFTWOCITIES
# 332749 2009-11-29        SQUEALOFAPPROVAL
# 42830  2020-04-22        THIRTEENCOLONIES
# 46316  2020-03-08        SALTLAKECITYUTAH
# 59570  2019-09-16        JUSTFORTHERECORD
# 72252  2019-04-03        NORTHWESTPASSAGE
# 81870  2018-11-28        FRENCHREVOLUTION
# 92177  2018-07-15        OUTSTANDINGBILLS
# 96885  2018-05-13        FRENCHCONNECTION
# 99759  2018-04-06        DOYOUWANTTODANCE
# 103939 2018-02-10        INALLPROBABILITY
# 108554 2017-12-10        DENZELWASHINGTON
# 111447 2017-11-02        MANHATTANPROJECT
# 128356 2017-03-26        ACLOCKWORKORANGE
# 142653 2016-09-19        HOLLYWOODSQUARES
# 143265 2016-09-11        BLANKETSTATEMENT
# 161884 2016-01-12        INTERIORDESIGNER
# 181508 2015-05-01        THESCARLETLETTER
# 181527 2015-05-01        ADRENALINEJUNKIE
# 187033 2015-02-17        WHOLETTHEDOGSOUT
# 203549 2014-07-17        FALLBACKPOSITION
# 203557 2014-07-17        QUARTERBACKSNEAK
# 296358 2011-03-20        THEMALTESEFALCON
# 781544 1993-11-21        SHRINKINGVIOLETS
#
#                                                      Clue  DayofWeek  lengths  \
# 76762            Seeming opposite of "Ignorance is bliss"          6       22
# 215356  1963 movie with the tagline "Everybody who's e...          3       21
# 260451         See 28-, 39-, 45-, 83-, 95- and 107-Across          6       21
# 204390  This puzzle's theme, whose first notes are ind...          6       21
# 302230  1943 novel "Whaddya Tink? A Sapling Stays a Sa...          6       20
# 425623      Nose-picking and belching in the White House?          6       20
# 24814                                   Indy film? (1981)          6       19
# 378484  Some moralizing about getting off a balance beam?          6       19
# 347298  *Alexander Pope phrase appropriate to the star...          6       18
# 159905                Ones giving the waiter a hard time?          6       18
# 173025             1970s TV series set at 165 Eaton Place          3       18
# 370380                    Popular 1970s British TV series          6       18
# 347254                      *Bond film that's a real gem?          6       18
# 226669                       Adage regarding skittishness          2       18
# 163910  Alcoholic drink so named because of its color,...          3       17
# 236576       This puzzle's long-winded advice, simply put          6       17
# 263658                 Two reasons to avoid a dog kennel?          6       17
# 302220            1951 film "Une Personne des Etats-Unis"          6       17
# 351580  1951 Oscar-winning film whose title suggests a...          6       17
# 172249     "You can't judge a book by its cover, but ..."          6       17
# 172201                "He who hesitates is lost, but ..."          6       17
# 166838                    1982 Arnold Schwarzenegger film          6       17
# 343040                                 Sodom or Gomorrah?          6       17
# 15054   Popular action film franchise ... or what tryi...          6       17
# 224771                         Movie franchise since 1996          6       17
# 641697                      Dickens classic, to a cowboy?          3       17
# 577007                          1947 Best Picture nominee          3       17
# 48156   Reference that arranges words by concept rathe...          3       17
# 716632               Senor Ferrari player in "Casablanca"          6       17
# 63994                           Announcement of July 1969          6       17
# 681775                              Divots, for instance?          6       17
# 86840   1929 work that is the theme of this puzzle, wi...          6       17
# 429423  Dear old dad the cosmetic surgeon always told ...          6       17
# 516223  Unfinished Norman Mailer work about strip-sear...          6       17
# 137144  Classic novel about an orphan girl mistakenly ...          3       17
# 355895                                   *Chaperon's job?          6       16
# 626359                 John Huston's film-directing debut          6       16
# 632912                                            LIAISON          6       16
# 476891                             Book about Rosa Parks?          6       16
# 545155           Product of a Weight Watchers/FTD merger?          6       16
# 402038                          Matter of W.W. II secrecy          6       16
# 708574                                            Spoiler          6       16
# 353710                       *Good and bad for a motorist          6       16
# 476928                               Book about a mutiny?          6       16
# 756094                                   Unexpected hitch          6       16
# 781524            Novel that features the language Nadsat          6       16
# 474825     Rule barring players from dating cheerleaders?          6       16
# 594                                     Blackjack dealer?          6       16
# 343340   Dickens novel with the 56-Across as its backdrop          1       16
# 332749                             Delighted exclamation?          6       16
# 42830                Location in the New World until 1776          2       16
# 46316                         2002 Winter Olympics locale          6       16
# 59570   "To be totally clear" ... or why to bring in a...          0       16
# 72252                               *Roald Amundsen, 1906          2       16
# 81870   Historical event suggested by each of the six ...          2       16
# 92177                           Compliment to a lawmaker?          6       16
# 96885          Good name for a deep kissers' dating site?          6       16
# 99759   1958 Bobby Freeman hit covered by the Beach Bo...          4       16
# 103939                                   Almost certainly          5       16
# 108554                         "Training Day" actor, 2001          6       16
# 111447                     Steps 4 and 6: A 1940s program          3       16
# 128356                             Dystopian film of 1971          6       16
# 142653  Classic TV game show ... or what 18-, 25-, 55-...          0       16
# 143265            There are no ifs, ands or buts about it          6       16
# 161884  Elle Decor reader ... or any of the names hidd...          1       16
# 181508                       Provider of an A in English?          4       16
# 181527                            Many an extreme athlete          4       16
# 187033  2000 novelty hit ... or a hint to the answers ...          1       16
# 203549                                  Plan B, literally          3       16
# 203557                       Gridiron maneuver, literally          3       16
# 296358                           Chick lit book #6 (1930)          6       16
# 781544                               Self-effacing people          6       16
#
#         vowelratio
# 76762        0.409
# 215356       0.333
# 260451       0.381
# 204390       0.286
# 302230       0.400
# 425623       0.350
# 24814        0.368
# 378484       0.368
# 347298       0.333
# 159905       0.333
# 173025       0.333
# 370380       0.333
# 347254       0.444
# 226669       0.389
# 163910       0.412
# 236576       0.588
# 263658       0.353
# 302220       0.471
# 351580       0.471
# 172249       0.353
# 172201       0.588
# 166838       0.412
# 343040       0.412
# 15054        0.412
# 224771       0.412
# 641697       0.412
# 577007       0.412
# 48156        0.471
# 716632       0.412
# 63994        0.412
# 681775       0.412
# 86840        0.471
# 429423       0.353
# 516223       0.412
# 137144       0.412
# 355895       0.375
# 626359       0.375
# 632912       0.312
# 476891       0.438
# 545155       0.312
# 402038       0.312
# 708574       0.375
# 353710       0.250
# 476928       0.312
# 756094       0.375
# 781524       0.375
# 474825       0.375
# 594          0.375
# 343340       0.500
# 332749       0.438
# 42830        0.438
# 46316        0.438
# 59570        0.312
# 72252        0.312
# 81870        0.375
# 92177        0.312
# 96885        0.312
# 99759        0.500
# 103939       0.438
# 108554       0.312
# 111447       0.312
# 128356       0.375
# 142653       0.438
# 143265       0.312
# 161884       0.438
# 181508       0.312
# 181527       0.500
# 187033       0.375
# 203549       0.375
# 203557       0.375
# 296358       0.375
# 781544       0.312

# %%
#messing with wordcloud- probably not a great device to use here, but it works!
from wordcloud import WordCloud
x = longwords['Word'].tolist()
unique_string = (' ').join(x)
wordcloud = WordCloud(width = 1000, height = 500).generate(unique_string)
plt.figure(figsize = (15,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# http://amueller.github.io/word_cloud/

# %%
#view puzzles by day
monmask = df['DayofWeek'] == 0
mon = df[monmask]

tuesmask = df['DayofWeek'] == 1
tues = df[tuesmask]

wedmask = df['DayofWeek'] == 2
wed = df[wedmask]

thursmask = df['DayofWeek'] == 3
thurs = df[thursmask]

frimask = df['DayofWeek'] == 4
fri = df[frimask]

satmask = df['DayofWeek'] == 5
sat = df[satmask]

sunmask = df['DayofWeek'] == 6
sun = df[sunmask]

# %%
# monlengths = mon.value_counts('lengths').sort_index().plot(kind = 'bar')
# monlengths.set_ylabel('# of occurrences')
# monlengths.set_title("Monday's Words Tend Shorter")

mon.value_counts('lengths').sort_index()
# Out:
# lengths
# 3     21538
# 4     39522
# 5     26898
# 6     10074
# 7      4013
# 8      1863
# 9       983
# 10      866
# 11      451
# 12      142
# 13      107
# 14       61
# 15      451
# 16        2
# Name: count, dtype: int64

# %%
# wedlengths = wed.value_counts('lengths').sort_index().plot(kind = 'bar')
# wedlengths.set_ylabel('# of occurrences')
# wedlengths.set_title("Compared to Wednesday, Average Word Longer")
wed.value_counts('lengths').sort_index()
# Out:
# lengths
# 3     23184
# 4     35351
# 5     25099
# 6     11156
# 7      4596
# 8      2293
# 9       901
# 10      547
# 11      288
# 12       87
# 13       81
# 14       42
# 15      281
# 16        3
# 18        1
# Name: count, dtype: int64

# %%
satlengths = sat.value_counts('lengths').sort_index().plot(kind = 'bar')
satlengths.set_ylabel('# of occurrences')
satlengths.set_title("Saturday's Average Word is Longest")
# Out:
# Text(0.5, 1.0, "Saturday's Average Word is Longest")

# %%
fig,ax = plt.subplots()
sat.value_counts('lengths').sort_index().plot(kind = 'bar', ax = ax, color = 'blue', label = 'saturday')
mon.value_counts('lengths').sort_index().plot(kind = 'bar', ax = ax, alpha = .5, color = 'red', label = 'monday')
plt.legend()
fig.suptitle('Longer Words Throughout The Week (Monday vs Saturday)')
# Out:
# Text(0.5, 0.98, 'Longer Words Throughout The Week (Monday vs Saturday)')

# %%
#boxplot to compare the difficulties (expressed in word length)
#rough, but conveys that wthe average word length gets longer over the week
#I'd like to clean this up
df_dayvslength = df[['DayofWeek', 'lengths']]
df_dayvslength.boxplot(by = 'DayofWeek', column = 'lengths', vert = False)
plt.ylabel('wordlengths')
# Out:
# Text(0, 0.5, 'wordlengths')

# %%
#second attempt- not quite right
import seaborn as sns
sns.set(style='darkgrid')
my_order = df.groupby(by =['DayofWeek'])['lengths'].median().iloc[::-1].index
sns.boxplot(x='lengths', y='DayofWeek', data = df, order = my_order)
plt.show()

# %%
#I want to cross reference the wordcounts list with a list of commonly used english words-
#delete common ones, result is a list of effective words to learn.
#Then with a few of the top words on this list, trace their use in the puzzles to confirm they're worthwile
# text from https://www.wordfrequency.info/samples.asp
#top 5050 words in modern english usage
def listinlist(list1, list2):
    return [x for x in list1 if x not in list2]

import csv
with open('top5050words.csv') as f:
    top5050 = []
    wordlist = csv.reader(f)
    for word in wordlist:
        top5050.append(word[0].upper())

#top5050 is list of all caps strings

wordcounts = df['Word'].value_counts()
nytwordsinfreqorder = wordcounts.index.tolist()

#compare nytwordsinfreqorder- delete anything in top5050, see what happens

wordstostudy = listinlist(nytwordsinfreqorder, top5050)

#makes a list, but now I've lost the value counts, not as much info,
# Out:
# 59684

# %%
wcdf = pd.DataFrame(wordcounts).reset_index()
# wcdf

subset = wcdf.loc[(~wcdf["Word"].isin(top5050)) & (wcdf['count'] > 200)]
subset
# Out:
#      Word  count
# 2     ERE    510
# 4     ELI    493
# 5     ORE    489
# 6     ALE    474
# 8     ETA    465
# ..    ...    ...
# 241   NEA    202
# 242   AVE    202
# 243  NEAT    202
# 244  AFAR    201
# 245  RENE    201
#
# [169 rows x 2 columns]

# %%
y = subset['Word'].tolist()
unique_string = (' ').join(y)
wordcloud = WordCloud(width = 1000, height = 500).generate(unique_string)
plt.figure(figsize = (15,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
